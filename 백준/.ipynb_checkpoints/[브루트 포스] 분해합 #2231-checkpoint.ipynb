# %% [markdown]
# https://www.acmicpc.net/problem/2231
# ![image.png](attachment:image.png)

# %%
n = int(input())

answer = 0

for i in range(1, n):
    nlist = [int(j) for j in list(str(i))]
    if sum(nlist) + i == n:
        answer = i
        break

print(answer)
# Out:
# 216
# 198
