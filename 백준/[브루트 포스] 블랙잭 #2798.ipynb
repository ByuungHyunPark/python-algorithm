# %% [markdown]
# https://www.acmicpc.net/problem/2798
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### pythonic한 풀이

# %%
N, M = map(int, input().split())
card_num_list = [int(i)for i in input().split()]

from itertools import combinations

card3_sum_list = [sum(i) for i in list(combinations(card_num_list, 3))]

print(max([i for i in sorting_similar_card if i <= M]))
# Out:
# 10 500
# 93 181 245 214 315 36 185 138 216 295
# 497
