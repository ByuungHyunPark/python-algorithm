# %% [markdown]
# https://www.acmicpc.net/problem/1018
# ![image.png](attachment:image.png)

# %%
#input
n, m = map(int, input().split())
mat = []
for _ in range(n):
    mat.append(input())
        

# 생각보다 잘 안풀림.. 추후 다시 생각해보며 진행
# CNN 처럼 구현하고자 하였는데 자 ㄹ안돰
# Out:
# 3 3
# aaa
# bbb
# ccc
